# %%
import os
import pandas
import codecs
import glob
import pandas as pd

os.getcwd()
os.chdir(r"C:\Users\mintylee\Desktop\EL-SMURF-master\dataset\dset72_label")


def txtcombine():
    files = glob.glob('*.txt')

    all = codecs.open(r'C:\Users\mintylee\Desktop\72_la.txt', 'a')

    for filename in files:
        print(filename)
        fopen = codecs.open(filename, 'r', encoding='utf-8')

        lines = fopen.readlines()
        del lines[0:4]
        del lines[-1]
        del lines[-1]
        del lines[-1]
        del lines[-1]
        fopen.close()
        for x in lines:
            # if len(lines)>4:
            all.write(x)
        # 读取为DataFrame格式
        all1 = pd.read_csv(r'C:\Users\mintylee\Desktop\72_la.txt', sep=' ', encoding='GB2312')
        # 保存为csv格式
        all1.to_csv('72_la.csv', encoding='GB2312')

if __name__ == '__main__':
    txtcombine()
# Out:
# 1ak4A.txt
# 1ak4D.txt
# 1b6cA.txt
# 1b6cB.txt
# 1dfjE.txt
# 1dfjI.txt
# 1e4kAB.txt
# 1e4kC.txt
# 1e6eA.txt
# 1e6eB.txt
# 1eerA.txt
# 1eerBC.txt
# 1efnA.txt
# 1efnB.txt
# 1ewyA.txt
# 1ewyC.txt
# 1f34A.txt
# 1f34B.txt
# 1fc2C.txt
# 1fc2D.txt
# 1gcqB.txt
# 1gcqC.txt
# 1ghqA.txt
# 1ghqB.txt
# 1glaF.txt
# 1glaG.txt
# 1ib1AB.txt
# 1ib1E.txt
# 1jmoA.txt
# 1jmoLH.txt
# 1k5dAB.txt
# 1k5dC.txt
# 1k74AB.txt
# 1k74DE.txt
# 1kacA.txt
# 1kacB.txt
# 1kklABC.txt
# 1kklH.txt
# 1ktzA.txt
# 1ktzB.txt
# 1mahA.txt
# 1mahF.txt
# 1ml0A.txt
# 1ml0D.txt
# 1n2cABCD.txt
# 1n2cEF.txt
# 1nw9A.txt
# 1nw9B.txt
# 1pxvA.txt
# 1pxvC.txt
# 1qa9A.txt
# 1qa9B.txt
# 1rlbABCD.txt
# 1rlbE.txt
# 1udiE.txt
# 1udiI.txt
# 1xqsA.txt
# 1xqsC.txt
# 1yvbA.txt
# 1yvbI.txt
# 2ajfA.txt
# 2ajfE.txt
# 2hqsA.txt
# 2hqsH.txt
# 2hrkA.txt
# 2hrkB.txt
# 2mtaA.txt
# 2mtaHL.txt
# 2o8vA.txt
# 2o8vB.txt
# 7ceiA.txt
# 7ceiB.txt
